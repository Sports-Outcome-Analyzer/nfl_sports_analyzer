# %%
import requests
import pandas as pd
import numpy as np
from pandas import json_normalize

# %%
response = requests.get('https://api.sportsdata.io/v3/nfl/scores/json/TeamSeasonStats/2020REG?key=d8b5ea01537141eb9a320f95994b7109')

# %%
df = pd.DataFrame.from_dict(response.json())

# %%
df.head()
df['average_score'] = round((df['Score'] / df['Games']), 2)

# %%
df.head()
# Out:
#    SeasonType  Season Team  Score  OpponentScore  TotalScore  Temperature  \
# 0           1    2020  ARI    234            180         414           82
# 1           1    2020  ATL    243            251         494           73
# 2           1    2020  BAL    227            142         369           71
# 3           1    2020  BUF    242            233         475           70
# 4           1    2020  CAR    210            226         436           73
#
#    Humidity  WindSpeed  OverUnder  ...  Games  PassingDropbacks  \
# 0        81          9       55.8  ...      8               314
# 1        66         11       56.8  ...      9               404
# 2        77         11       52.3  ...      8               258
# 3        72          8       51.9  ...      9               370
# 4        59          9       53.5  ...      9               358
#
#    OpponentPassingDropbacks  TeamSeasonID  TwoPointConversionReturns  \
# 0                       349     201000001                          0
# 1                       397     201000002                          0
# 2                       361     201000036                          0
# 3                       354     201000037                          0
# 4                       372     201000005                          0
#
#    OpponentTwoPointConversionReturns TeamID  GlobalTeamID  TeamStatID  \
# 0                                  0      1             1   201000001
# 1                                  0      2             2   201000002
# 2                                  0      3             3   201000036
# 3                                  0      4             4   201000037
# 4                                  0      5             5   201000005
#
#    average_score
# 0          29.25
# 1          27.00
# 2          28.38
# 3          26.89
# 4          23.33
#
# [5 rows x 226 columns]
